# %%
import matplotlib.pyplot as plt
import numpy as np

# Capacité des matériaux

C = np.array([480, 500, 820, 3900])
M = np.array([112.411, 65.38, 107.86, 3900])
z = np.array([2,2,1,1])

plt.plot(z/M, C, 'ro')
